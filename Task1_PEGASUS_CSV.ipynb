# %%
import pandas as pd
from transformers import PegasusTokenizer, PegasusForConditionalGeneration
import torch

# %%
# Load the Pegasus tokenizer and model
model_name = "google/pegasus-xsum"
tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:99: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/87.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.52M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-xsum and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/259 [00:00<?, ?B/s]

# %%
# Function to summarize a given text using Pegasus
def summarize_text(text):
    # Tokenize the input text
    inputs = tokenizer(text, truncation=True, padding="longest", return_tensors="pt")
    # Generate the summary
    summary_ids = model.generate(inputs.input_ids, max_length=60, num_beams=5, early_stopping=True)
    # Decode the summary
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# %%
# Step 1: Load the CSV file
csv_file_path = 'medical_text_summarization_detailed.csv'  # Provide the correct path to the file
df = pd.read_csv(csv_file_path)

# %%
df
# Out:
#                                          Original Text  \
# 0    60-year-old female presented with a diagnosis ...
# 1    65-year-old male presented with a diagnosis of...
# 2    65-year-old male presented with a diagnosis of...
# 3    45-year-old male presented with a diagnosis of...
# 4    55-year-old male presented with a diagnosis of...
# ..                                                 ...
# 495  60-year-old female presented with a diagnosis ...
# 496  70-year-old female presented with a diagnosis ...
# 497  80-year-old female presented with a diagnosis ...
# 498  75-year-old female presented with a diagnosis ...
# 499  40-year-old male presented with a diagnosis of...
#
#                                        Summarized Text
# 0    60-year-old female with diabetes, initial vita...
# 1    65-year-old male with chronic kidney disease, ...
# 2    65-year-old male with depression, initial vita...
# 3    45-year-old male with Alzheimer's disease, ini...
# 4    55-year-old male with diabetes, initial vitals...
# ..                                                 ...
# 495  60-year-old female with stroke, initial vitals...
# 496  70-year-old female with rheumatoid arthritis, ...
# 497  80-year-old female with heart failure, initial...
# 498  75-year-old female with Alzheimer's disease, i...
# 499  40-year-old male with Alzheimer's disease, ini...
#
# [500 rows x 2 columns]

# %%
# Step 2: Summarize texts from the CSV
df['Generated Summary'] = df['Original Text'].apply(summarize_text)

# Save the updated dataframe with summaries to a new CSV
df.to_csv('summarized_medical_texts.csv', index=False)

print("Summaries generated and saved to summarized_medical_texts.csv.")
# Out:
# Summaries generated and saved to summarized_medical_texts.csv.

# %%
# Step 3: Allow user to input text for summarization
def user_input_summarization():
    user_text = input("Enter the medical text you want to summarize: ")
    summary = summarize_text(user_text)
    print(f"Summary: {summary}")

# Call the user input function at the end
user_input_summarization()
# Out:
# Enter the medical text you want to summarize: Patient is showing symptoms of fever, cough, and shortness of breath. X-rays suggest possible pneumonia. The patient is on antibiotics and is responding well to treatment.
# Summary: A patient in his 70s has been diagnosed with a respiratory illness.
